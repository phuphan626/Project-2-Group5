# %% [markdown]
# # Project 2 - Group 5
# ## Team member:
# * Phu Phan
# * John Shows
# * Marvin Gayle
# * Tyler Stridiron

# %% [markdown]
# # Pitching Averages Cleanup

# %%
# Import Dependencies
import pandas as pd
from config import my_key
import json

# %%
# Set the main url, then read in the table. There are two tables in the web page. We picked the Pitching Averages table.
# The first one is "League Year-By-Year Pitching--Averages"
baseball_url='https://www.baseball-reference.com/leagues/MLB/pitch.shtml'
pitching_average_table=pd.read_html(baseball_url)[0]
# The second one is "League Year-By-Year Pitching--Totals"
pitching_total_table=pd.read_html(baseball_url)[1]

# %%
# Convert it to a dataframe 
pitching_average_df=pd.DataFrame(pitching_average_table)

# %%
# Set the index to Year column for later cleaning
pitching_average_df=pitching_average_df.set_index('Year')

# %%
# Display the table
pitching_average_df
# Out:
#       Tms   #P  PAge    R/G   ERA     G    GF    CG   SHO  tSho  ...     BF  \
# Year                                                             ...
# 2020   30  729  28.3   4.64  4.44  1698  0.98  0.02  0.01  0.05  ...  37.07
# 2019   30  831  28.4   4.83  4.49  4858  0.99  0.01  0.01  0.06  ...  38.39
# 2018   30  799  28.4   4.45  4.14  4862  0.99  0.01  0.00  0.06  ...  38.08
# 2017   30  755  28.5   4.65  4.35  4860  0.99  0.01  0.01  0.05  ...  38.13
# 2016   30  742  28.3   4.48  4.18  4856  0.98  0.02  0.01  0.06  ...  38.01
# ...   ...  ...   ...    ...   ...   ...   ...   ...   ...   ...  ...    ...
# 1874    8   17  24.7   7.48  2.19   464  0.05  0.95  0.03  0.03  ...  41.69
# 1873    9   25  21.3   8.99  3.40   398  0.09  0.91  0.02  0.02  ...  43.45
# 1872   11   21  21.1   9.26  3.65   366  0.11  0.89  0.03  0.03  ...  43.52
# 1871    9   19  24.6  10.47  4.22   254  0.09  0.91  0.02  0.02  ...  44.15
# ...

# %% [markdown]
# ## We notice that when pandas reads in the table, there are some duplicate rows that do not contain the decimal value. Therefore, we want to drop them out of the table. Also the table has 32 columns, which is redundant, so we filter out some columns, and keep the necessary ones.

# %%
# Filter out the duplicate headers as rows
rows_to_drop=pitching_average_df.loc['Year']

# %%
# Display to check
rows_to_drop
# Out:
#       Tms  #P  PAge  R/G  ERA  G  GF  CG  SHO  tSho  ...  BF  ERA+  WHIP  \
# Year                                                 ...
# Year  Tms  #P  PAge  R/G  ERA  G  GF  CG  SHO  tSho  ...  BF  ERA+  WHIP
# Year  Tms  #P  PAge  R/G  ERA  G  GF  CG  SHO  tSho  ...  BF  ERA+  WHIP
# Year  Tms  #P  PAge  R/G  ERA  G  GF  CG  SHO  tSho  ...  BF  ERA+  WHIP
# Year  Tms  #P  PAge  R/G  ERA  G  GF  CG  SHO  tSho  ...  BF  ERA+  WHIP
# Year  Tms  #P  PAge  R/G  ERA  G  GF  CG  SHO  tSho  ...  BF  ERA+  WHIP
# Year  Tms  #P  PAge  R/G  ERA  G  GF  CG  SHO  tSho  ...  BF  ERA+  WHIP
#
#       BAbip  H9  HR9  BB9  SO9  SO/W  E
# Year
# Year  BAbip  H9  HR9  BB9  SO9  SO/W  E
# Year  BAbip  H9  HR9  BB9  SO9  SO/W  E
# Year  BAbip  H9  HR9  BB9  SO9  SO/W  E
# Year  BAbip  H9  HR9  BB9  SO9  SO/W  E
# Year  BAbip  H9  HR9  BB9  SO9  SO/W  E
# Year  BAbip  H9  HR9  BB9  SO9  SO/W  E
#
# [6 rows x 32 columns]

# %%
# Drop out those unnecessary rows
cleaned_baseball_df=pitching_average_df[pitching_average_df['Tms'].isin(rows_to_drop)==False]

# %%
# Checking the length of the df. The original has 156 rows, so the cleaned up one should have 150 rows after dropping.
len(cleaned_baseball_df)
# Out:
# 150

# %%
# Dropping those unnecessary columns
cleaned_baseball_df=cleaned_baseball_df[['Tms','R/G','ERA','GF','CG','HR','SO','HBP','HR9','SO9']]

# %%
# Reset index to Year column
cleaned_baseball_df=cleaned_baseball_df.reset_index()

# %%
# Convert the Year to integer
cleaned_baseball_df['Year']=cleaned_baseball_df['Year'].astype(int)

# %%
# Get data from 1920 and up.
cleaned_baseball_df=cleaned_baseball_df.loc[(cleaned_baseball_df['Year']>=1920)]

# %%
# Convert the rest of columns to float type, so we can load them into PostgreSQL
cleaned_baseball_df[['Tms','R/G','ERA','GF','CG','HR','SO','HBP','HR9','SO9']]=cleaned_baseball_df[['Tms','R/G','ERA','GF','CG','HR','SO','HBP','HR9','SO9']].astype(float)

# %%
# Display the final table
cleaned_baseball_df
# Out:
#      Year   Tms   R/G   ERA    GF    CG    HR    SO   HBP  HR9  SO9
# 0    2020  30.0  4.64  4.44  0.98  0.02  1.28  8.67  0.46  1.3  9.1
# 1    2019  30.0  4.83  4.49  0.99  0.01  1.39  8.81  0.41  1.4  8.9
# 2    2018  30.0  4.45  4.14  0.99  0.01  1.15  8.48  0.40  1.2  8.5
# 3    2017  30.0  4.65  4.35  0.99  0.01  1.26  8.25  0.36  1.3  8.3
# 4    2016  30.0  4.48  4.18  0.98  0.02  1.16  8.03  0.34  1.2  8.1
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...  ...  ...
# 96   1924  16.0  4.75  4.05  0.51  0.49  0.36  2.69  0.22  0.4  2.7
# 97   1923  16.0  4.81  3.99  0.51  0.49  0.40  2.84  0.25  0.4  2.9
# 98   1922  16.0  4.86  4.06  0.50  0.50  0.43  2.80  0.25  0.4  2.8
# 99   1921  16.0  4.85  4.03  0.48  0.52  0.38  2.83  0.23  0.4  2.8
# 100  1920  16.0  4.36  3.46  0.43  0.57  0.26  2.95  0.22  0.3  2.9
#
# [101 rows x 11 columns]

# %%
# Rename columnd R/G to RG for using the json
cleaned_baseball_df=cleaned_baseball_df.rename(columns={'R/G':'RG'})

# %%
# Export to html format to use in the index.html
cleaned_baseball_df.to_html('html_files/pitching.html')

# %%
# Export wo json format for visualization
cleaned_baseball_df.to_json('static/pitching.json',orient='records')

# %% [markdown]
# # Batting Cleanup

# %%
# Doing the cleanup for batting stats
batting_url = "https://www.baseball-reference.com/leagues/MLB/bat.shtml"
batting_table = pd.read_html(batting_url)[0]

# %%
# Convert it to DataFrame
batting_df = pd.DataFrame(batting_table)
batting_df
# Out:
#      Year  Tms  #Bat  BatAge    R/G     G     PA     AB      R      H  ...  \
# 0    2020   30   609    28.0   4.64  1698  37.07  32.90   4.64   8.05  ...
# 1    2019   30  1287    27.9   4.83  4858  38.39  34.30   4.83   8.65  ...
# 2    2018   30  1271    28.1   4.45  4862  38.08  34.03   4.45   8.44  ...
# 3    2017   30  1229    28.3   4.65  4860  38.13  34.07   4.65   8.69  ...
# 4    2016   30  1247    28.4   4.48  4856  38.01  34.09   4.48   8.71  ...
# ..    ...  ...   ...     ...    ...   ...    ...    ...    ...    ...  ...
# 151  1874    8   120    25.0   7.48   464  41.69  41.17   7.48  11.26  ...
# 152  1873    9   122    24.0   8.99   398  43.45  42.61   8.99  12.38  ...
# 153  1872   11   143    23.5   9.26   366  43.52  42.80   9.26  12.20  ...
# 154  1871    9   115    23.9  10.47   254  44.15  42.61  10.47  12.21  ...
# 155  Year  Tms  #Bat  BatAge    R/G     G     PA     AB      R      H  ...
#
#        BA   OBP   SLG   OPS     TB   GDP   HBP    SH    SF   IBB
# ...

# %%
# Setting the index to Year column
batting_df = batting_df.set_index('Year')

# %%
# Filter out unnecessary rows as above
drop_rows = batting_df.loc['Year']
drop_rows
# Out:
#       Tms  #Bat  BatAge  R/G  G  PA  AB  R  H  2B  ...  BA  OBP  SLG  OPS  TB  \
# Year                                               ...
# Year  Tms  #Bat  BatAge  R/G  G  PA  AB  R  H  2B  ...  BA  OBP  SLG  OPS  TB
# Year  Tms  #Bat  BatAge  R/G  G  PA  AB  R  H  2B  ...  BA  OBP  SLG  OPS  TB
# Year  Tms  #Bat  BatAge  R/G  G  PA  AB  R  H  2B  ...  BA  OBP  SLG  OPS  TB
# Year  Tms  #Bat  BatAge  R/G  G  PA  AB  R  H  2B  ...  BA  OBP  SLG  OPS  TB
# Year  Tms  #Bat  BatAge  R/G  G  PA  AB  R  H  2B  ...  BA  OBP  SLG  OPS  TB
# Year  Tms  #Bat  BatAge  R/G  G  PA  AB  R  H  2B  ...  BA  OBP  SLG  OPS  TB
#
#       GDP  HBP  SH  SF  IBB
# Year
# Year  GDP  HBP  SH  SF  IBB
# Year  GDP  HBP  SH  SF  IBB
# Year  GDP  HBP  SH  SF  IBB
# Year  GDP  HBP  SH  SF  IBB
# Year  GDP  HBP  SH  SF  IBB
# Year  GDP  HBP  SH  SF  IBB
#
# [6 rows x 27 columns]

# %%
# Drop those rows
batting_cleaned_df = batting_df[batting_df['Tms'].isin(drop_rows)==False]

# %%
# Checking the length of the cleaned table
len(batting_cleaned_df)
# Out:
# 150

# %%
# Fill the NaN cells with 0
batting_cleaned_df = batting_cleaned_df.fillna(0)
batting_cleaned_df
# Out:
#      Tms  #Bat BatAge    R/G     G     PA     AB      R      H    2B  ...  \
# Year                                                                  ...
# 2020  30   609   28.0   4.64  1698  37.07  32.90   4.64   8.05  1.58  ...
# 2019  30  1287   27.9   4.83  4858  38.39  34.30   4.83   8.65  1.76  ...
# 2018  30  1271   28.1   4.45  4862  38.08  34.03   4.45   8.44  1.70  ...
# 2017  30  1229   28.3   4.65  4860  38.13  34.07   4.65   8.69  1.73  ...
# 2016  30  1247   28.4   4.48  4856  38.01  34.09   4.48   8.71  1.70  ...
# ...   ..   ...    ...    ...   ...    ...    ...    ...    ...   ...  ...
# 1875  13   189   24.7   6.14   690  39.25  38.89   6.14   9.87  1.22  ...
# 1874   8   120   25.0   7.48   464  41.69  41.17   7.48  11.26  1.37  ...
# 1873   9   122   24.0   8.99   398  43.45  42.61   8.99  12.38  1.43  ...
# 1872  11   143   23.5   9.26   366  43.52  42.80   9.26  12.20  1.59  ...
# 1871   9   115   23.9  10.47   254  44.15  42.61  10.47  12.21  1.71  ...
#
# ...

# %%
# Filter out desired columns
batting_cleaned_df = batting_cleaned_df[['Tms', '2B', '3B', 'SB', 'BA', 'OPS','HR']]
batting_cleaned_df
# Out:
#      Tms    2B    3B    SB    BA   OPS    HR
# Year
# 2020  30  1.58  0.13  0.49  .245  .740  1.28
# 2019  30  1.76  0.16  0.47  .252  .758  1.39
# 2018  30  1.70  0.17  0.51  .248  .728  1.15
# 2017  30  1.73  0.16  0.52  .255  .750  1.26
# 2016  30  1.70  0.18  0.52  .255  .739  1.16
# ...   ..   ...   ...   ...   ...   ...   ...
# 1875  13  1.22  0.40  0.91  .254  .571  0.06
# 1874   8  1.37  0.42  0.52  .273  .616  0.09
# 1873   9  1.43  0.53  0.79  .290  .661  0.12
# 1872  11  1.59  0.40  0.73  .285  .645  0.10
# 1871   9  1.71  0.94  1.74  .287  .695  0.19
#
# [150 rows x 7 columns]

# %%
# Reset the index
batting_cleaned_df = batting_cleaned_df.reset_index()

# %%
# Convert the Year column to integer type
batting_cleaned_df['Year'] = batting_cleaned_df['Year'].astype(int)

# %%
# Convert the rest to float type
batting_cleaned_df[['Tms', '2B', '3B', 'SB', 'BA', 'OPS','HR']]=batting_cleaned_df[['Tms', '2B', '3B', 'SB', 'BA', 'OPS','HR']].astype(float)

# %%
# Filter out cells before 1920
cleaned_date = batting_cleaned_df.loc[(batting_cleaned_df['Year']>=1920)]
cleaned_date
# Out:
#      Year   Tms    2B    3B    SB     BA    OPS    HR
# 0    2020  30.0  1.58  0.13  0.49  0.245  0.740  1.28
# 1    2019  30.0  1.76  0.16  0.47  0.252  0.758  1.39
# 2    2018  30.0  1.70  0.17  0.51  0.248  0.728  1.15
# 3    2017  30.0  1.73  0.16  0.52  0.255  0.750  1.26
# 4    2016  30.0  1.70  0.18  0.52  0.255  0.739  1.16
# ..    ...   ...   ...   ...   ...    ...    ...   ...
# 96   1924  16.0  1.66  0.48  0.61  0.287  0.742  0.36
# 97   1923  16.0  1.59  0.46  0.64  0.284  0.738  0.40
# 98   1922  16.0  1.59  0.50  0.59  0.288  0.749  0.43
# 99   1921  16.0  1.62  0.55  0.60  0.291  0.750  0.38
# 100  1920  16.0  1.46  0.51  0.70  0.276  0.707  0.26
#
# [101 rows x 8 columns]

# %%
# Rename the 2B and 3B to BB and BBB
cleaned_date=cleaned_date.rename(columns={'2B':'BB','3B':'BBB'})

# %%
# Export to html format
cleaned_date.to_html('html_files/batting.html')

# %%
# Export to json format
cleaned_date.to_json('static/batting.json',orient='records')

# %% [markdown]
# # Create connection to PostgreSQL

# %%
# Import Dependencies
import sqlalchemy
import psycopg2
from sqlalchemy import create_engine
from config import my_key

# %%
# SQL path
postgres_path=('postgresql://postgres:{password}@localhost:5432/project2-db'
               .format(password=my_key))

# %%
# Create engine and connection to database in pgAdmin
engine = create_engine(postgres_path)
connection = engine.connect()

# %%
# Import data from Pandas to SQL
cleaned_date.to_sql(name='batting_stats', con=connection, if_exists = 'append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1257                     self.dialect.do_executemany(
# -> 1258                         cursor, statement, parameters, context
#    1259                     )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#
# UndefinedColumn: column "BB" of relation "batting_stats" does not exist
# LINE 1: INSERT INTO batting_stats ("Year", "Tms", "BB", "BBB", "SB",...
#                                                   ^
#
#
# ...

# %%
cleaned_baseball_df.to_sql(name='pitching_averages', con=connection, if_exists = 'append', index=False)
