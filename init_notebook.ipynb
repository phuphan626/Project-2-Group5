# %%
import pandas as pd

# %%
baseball_url='https://www.baseball-reference.com/leagues/MLB/pitch.shtml'
baseball_tables=pd.read_html(baseball_url)[0]

# %%
baseball_df=pd.DataFrame(baseball_tables)

# %%
baseball_df=baseball_df.set_index('Year')

# %%
baseball_df
# Out:
#       Tms   #P  PAge    R/G   ERA     G    GF    CG   SHO  tSho  ...     BF  \
# Year                                                             ...
# 2020   30  710  28.4   4.70  4.50  1438  0.98  0.02  0.01  0.05  ...  37.17
# 2019   30  831  28.4   4.83  4.49  4858  0.99  0.01  0.01  0.06  ...  38.39
# 2018   30  799  28.4   4.45  4.14  4862  0.99  0.01  0.00  0.06  ...  38.08
# 2017   30  755  28.5   4.65  4.35  4860  0.99  0.01  0.01  0.05  ...  38.13
# 2016   30  742  28.3   4.48  4.18  4856  0.98  0.02  0.01  0.06  ...  38.01
# ...   ...  ...   ...    ...   ...   ...   ...   ...   ...   ...  ...    ...
# 1874    8   17  24.7   7.48  2.19   464  0.05  0.95  0.03  0.03  ...  41.69
# 1873    9   25  21.3   8.99  3.40   398  0.09  0.91  0.02  0.02  ...  43.45
# 1872   11   21  21.1   9.26  3.65   366  0.11  0.89  0.03  0.03  ...  43.52
# 1871    9   19  24.6  10.47  4.22   254  0.09  0.91  0.02  0.02  ...  44.15
# ...

# %%
rows_to_drop=baseball_df.loc['Year']

# %%
rows_to_drop
# Out:
#       Tms  #P  PAge  R/G  ERA  G  GF  CG  SHO  tSho  ...  BF  ERA+  WHIP  \
# Year                                                 ...
# Year  Tms  #P  PAge  R/G  ERA  G  GF  CG  SHO  tSho  ...  BF  ERA+  WHIP
# Year  Tms  #P  PAge  R/G  ERA  G  GF  CG  SHO  tSho  ...  BF  ERA+  WHIP
# Year  Tms  #P  PAge  R/G  ERA  G  GF  CG  SHO  tSho  ...  BF  ERA+  WHIP
# Year  Tms  #P  PAge  R/G  ERA  G  GF  CG  SHO  tSho  ...  BF  ERA+  WHIP
# Year  Tms  #P  PAge  R/G  ERA  G  GF  CG  SHO  tSho  ...  BF  ERA+  WHIP
# Year  Tms  #P  PAge  R/G  ERA  G  GF  CG  SHO  tSho  ...  BF  ERA+  WHIP
#
#       BAbip  H9  HR9  BB9  SO9  SO/W  E
# Year
# Year  BAbip  H9  HR9  BB9  SO9  SO/W  E
# Year  BAbip  H9  HR9  BB9  SO9  SO/W  E
# Year  BAbip  H9  HR9  BB9  SO9  SO/W  E
# Year  BAbip  H9  HR9  BB9  SO9  SO/W  E
# Year  BAbip  H9  HR9  BB9  SO9  SO/W  E
# Year  BAbip  H9  HR9  BB9  SO9  SO/W  E
#
# [6 rows x 32 columns]

# %%
cleaned_baseball_df=baseball_df[baseball_df['Tms'].isin(rows_to_drop)==False]

# %%
cleaned_baseball_df.head(50)
# Out:
#      Tms   #P  PAge   R/G   ERA     G    GF    CG   SHO  tSho  ...     BF  \
# Year                                                           ...
# 2020  30  710  28.4  4.70  4.50  1438  0.98  0.02  0.01  0.05  ...  37.17
# 2019  30  831  28.4  4.83  4.49  4858  0.99  0.01  0.01  0.06  ...  38.39
# 2018  30  799  28.4  4.45  4.14  4862  0.99  0.01  0.00  0.06  ...  38.08
# 2017  30  755  28.5  4.65  4.35  4860  0.99  0.01  0.01  0.05  ...  38.13
# 2016  30  742  28.3  4.48  4.18  4856  0.98  0.02  0.01  0.06  ...  38.01
# 2015  30  735  28.4  4.25  3.95  4858  0.98  0.02  0.01  0.07  ...  37.80
# 2014  30  692  28.5  4.07  3.74  4860  0.98  0.02  0.01  0.07  ...  37.85
# 2013  30  679  28.4  4.17  3.86  4862  0.97  0.03  0.01  0.07  ...  38.02
# 2012  30  662  28.4  4.32  4.01  4860  0.97  0.03  0.01  0.06  ...  37.90
# 2011  30  662  28.3  4.28  3.94  4858  0.96  0.04  0.02  0.07  ...  38.13
# 2010  30  635  28.4  4.38  4.07  4860  0.97  0.03  0.01  0.07  ...  38.18
# ...

# %%
columns_to_drop=
